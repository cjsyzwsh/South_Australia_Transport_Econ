# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import geopandas as gpd
# # import geoplot
# import pickle
# # import geoplot.crs as gcrs
# import statsmodels.api as sm

# %%
node_degree_df = pd.read_pickle('../../data_process/node_degree_df.pickle')
edge_degree_df = pd.read_pickle('../../data_process/edge_degree_df.pickle')

# %%
len(node_degree_df["SA2_MAIN16"].values)
# Out:
# 103

# %%
edge_degree_df.columns
# Out:
# Index(['timestamp', 'destination', 'state', 'origin', 'unique_agents',
#        'sum_stay_duration', 'total_stays', 'OD', 'class_ART', 'class_BUS',
#        'class_COLL', 'class_FREE', 'class_HWY', 'class_LOCL', 'class_SUBA',
#        'class_TRK2', 'class_TRK4', 'class_UND', 'num_jobs_000_persons_origin',
#        'sa2_code16_x', 'median_income_per_job_aud_origin',
#        'num_jobs_000_persons_destination', 'sa2_code16_y',
#        'median_income_per_job_aud_destination', 'od_duration_value',
#        'od_distance_value', 'road_counts', 'num_nodes_x', 'num_1degree_x',
#        'num_2degree_x', 'num_3degree_x', 'num_4degree_x',
#        'num_greater5degree_x', 'num_nodes_y', 'num_1degree_y', 'num_2degree_y',
#        'num_3degree_y', 'num_4degree_y', 'num_greater5degree_y'],
#       dtype='object')

# %%
# mount_path = "/mnt/c/Users/jason/Dropbox (MIT)/"
mount_path = "/Users/shenhaowang/Dropbox (MIT)/project_media_lab_South_Australia/"

# %%
poi_df = gpd.read_file(mount_path + "/SA data/dataSA/points/points.shp")

# %%
poi_df.head()
# Out:
#      osm_id timestamp                                             name  \
# 0  29240333      None                                             None
# 1  29398542      None                                             None
# 2  29491931      None  Adelaide Railway Station Tram Stop (To Adelaide
# 3  29491942      None                                             None
# 4  29492063      None                                             None
#
#               type                     geometry
# 0  traffic_signals  POINT (138.60119 -34.91082)
# 1         crossing  POINT (138.59423 -34.76718)
# 2        tram_stop  POINT (138.59739 -34.92171)
# 3   level_crossing  POINT (138.59949 -34.92299)
# 4  traffic_signals  POINT (138.59351 -34.92330)

# %%
sa2_south_au = gpd.read_file("../../data_process/shapefiles/sa2_south_au.shp")

# %%
sa2_south_au.shape
# Out:
# (172, 13)

# %%
sa2_south_au.head()
# Out:
#   SA2_MAIN16 SA2_5DIG16          SA2_NAME16 SA3_CODE16      SA3_NAME16  \
# 0  401011001      41001            Adelaide      40101   Adelaide City
# 1  401011002      41002      North Adelaide      40101   Adelaide City
# 2  401021003      41003      Adelaide Hills      40102  Adelaide Hills
# 3  401021004      41004  Aldgate - Stirling      40102  Adelaide Hills
# 4  401021005      41005  Hahndorf - Echunga      40102  Adelaide Hills
#
#   SA4_CODE16                    SA4_NAME16 GCC_CODE16        GCC_NAME16  \
# 0        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 1        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 2        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 3        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 4        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
#
#   STE_CODE16       STE_NAME16  AREASQKM16  \
# 0          4  South Australia     10.4824
# 1          4  South Australia      5.0909
# 2          4  South Australia    364.4390
# 3          4  South Australia    117.2141
# 4          4  South Australia    110.1516
#
#                                             geometry
# 0  POLYGON ((138.58096 -34.93024, 138.58094 -34.9...
# 1  POLYGON ((138.58214 -34.90424, 138.58287 -34.9...
# 2  POLYGON ((138.75610 -34.82107, 138.75567 -34.8...
# 3  POLYGON ((138.69440 -34.98807, 138.69514 -34.9...
# 4  POLYGON ((138.78877 -35.02474, 138.78889 -35.0...

# %%
print(len(poi_df.geometry))
# Out:
# 19701

# %%
# #make sure all points only in one area
# not_found_count = 0
# for i, centroid in enumerate(poi_df.geometry):
#     found = False
#     count = 0
#     l = []
#     if i%100 == 0: print(i)
#     for i, row in sa2_south_au.iterrows():
#         if row["geometry"].contains(centroid):
#             count += 1
#             l.append(row["geometry"])
#             found = True
#     if not found:
#         print("not found")
#         not_found_count += 1
#     if len(l) > 1:
#         print(l)
#make sure all points only in one area
# not_found_count = 0
# for i, centroid in enumerate(poi_df.geometry):
#     found = False
#     count = 0
#     l = []
#     if i%100 == 0: print(i)
#     for i, row in sa2_south_au.iterrows():
#         if centroid.within(row["geometry"]):
#             count += 1
#             l.append(row["geometry"])
#             found = True
#     if not found:
#         print("not found")
#         not_found_count += 1
#     if len(l) > 1:
#         print(l)

# %%
# print(not_found_count)

# %%
# type(sa2_south_au["SA2_MAIN16"].values[0])

# %%
poi_df
# Out:
#          osm_id timestamp                                             name  \
# 0      29240333      None                                             None
# 1      29398542      None                                             None
# 2      29491931      None  Adelaide Railway Station Tram Stop (To Adelaide
# 3      29491942      None                                             None
# 4      29492063      None                                             None
# ...         ...       ...                                              ...
# 19696 -96119825      None                                             None
# 19697 -96119806      None                                             None
# 19698 -89932813      None                  Stop S1 Halifax St - South side
# 19699 -89932812      None                  Stop H1 Halifax St - North side
# 19700 -89932811      None                                             None
#
#                   type                     geometry
# 0      traffic_signals  POINT (138.60119 -34.91082)
# 1             crossing  POINT (138.59423 -34.76718)
# 2            tram_stop  POINT (138.59739 -34.92171)
# 3       level_crossing  POINT (138.59949 -34.92299)
# 4      traffic_signals  POINT (138.59351 -34.92330)
# ...                ...                          ...
# 19696     storage_tank  POINT (138.72106 -34.91859)
# 19697     storage_tank  POINT (138.72202 -34.91887)
# 19698         bus_stop  POINT (138.60730 -34.93265)
# 19699         bus_stop  POINT (138.60744 -34.93246)
# 19700            bench  POINT (138.60682 -34.93309)
#
# [19701 rows x 5 columns]

# %%
sa_codes_poi = []
for i, centroid in enumerate(poi_df.geometry):
    if i%100 == 0: print(i)
    found = False
    for i, row in sa2_south_au.iterrows():
        if row["geometry"].contains(centroid):
            sa_codes_poi.append(row["SA2_MAIN16"])
            found = True
            break
    if not found:
        sa_codes_poi.append("0")
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700

# %%
poi_df.to_pickle("../../data_process/poi_df.pickle")
poi_df = pd.read_pickle("../../data_process/poi_df.pickle")
poi_df["SA2_MAIN16"] = sa_codes_poi

# %%
# np.sum(poi_df["SA2_MAIN16"] == '0')
# Out:
# 22

# %%
print(len(poi_df))
poi_df = poi_df[poi_df["SA2_MAIN16"]!="0"]
print(len(poi_df))
# Out:
# 19701
# 19679

# %%
poi_df.head()
# Out:
#      osm_id timestamp                                             name  \
# 0  29240333      None                                             None
# 1  29398542      None                                             None
# 2  29491931      None  Adelaide Railway Station Tram Stop (To Adelaide
# 3  29491942      None                                             None
# 4  29492063      None                                             None
#
#               type                     geometry SA2_MAIN16
# 0  traffic_signals  POINT (138.60119 -34.91082)  401011002
# 1         crossing  POINT (138.59423 -34.76718)  402041044
# 2        tram_stop  POINT (138.59739 -34.92171)  401011001
# 3   level_crossing  POINT (138.59949 -34.92299)  401011001
# 4  traffic_signals  POINT (138.59351 -34.92330)  401011001

# %%
count = poi_df.groupby(["SA2_MAIN16"],as_index=False).aggregate(["count"])

# %%
count.head()
# Out:
#            osm_id timestamp  name  type geometry
#             count     count count count    count
# SA2_MAIN16
# 401011001    3288         0   757  3288     3288
# 401011002     756         0   152   756      756
# 401021004     279         0   181   279      279
# 401021010     153         0    56   153      153
# 401031011     276         0   141   276      276

# %%
# sw Q: How/why do we miss so many SA2's here?
count.shape
# Out:
# (76, 5)

# %%
count.columns
# Out:
# MultiIndex([(   'osm_id', 'count'),
#             ('timestamp', 'count'),
#             (     'name', 'count'),
#             (     'type', 'count'),
#             ( 'geometry', 'count')],
#            )

# %%
split_count = poi_df.groupby(["SA2_MAIN16","type"],as_index=False).aggregate(["count"])

# %%
split_count
# Out:
#                            osm_id timestamp  name geometry
#                             count     count count    count
# SA2_MAIN16 type
# 401011001  apartment            2         0     2        2
#            arts_centre          3         0     3        3
#            artwork              7         0     4        7
#            atm                 11         0     2       11
#            attraction          10         0    10       10
# ...                           ...       ...   ...      ...
# 404031109  toilets              1         0     0        1
#            traffic_signals      4         0     0        4
#            turning_circle      10         0     0       10
#            vending_machine      1         0     0        1
#            viewpoint            1         0     0        1
#
# [1799 rows x 4 columns]

# %%
for i, row in split_count.iterrows():
    print(row)
# Out:
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401011001, apartment), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401011001, arts_centre), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    4
# geometry   count    7
# Name: (401011001, artwork), dtype: int64
# osm_id     count    11
# timestamp  count     0
# name       count     2
# geometry   count    11
# Name: (401011001, atm), dtype: int64
# osm_id     count    10
# timestamp  count     0
# name       count    10
# geometry   count    10
# Name: (401011001, attraction), dtype: int64
# osm_id     count    24
# timestamp  count     0
# name       count    24
# geometry   count    24
# Name: (401011001, bank), dtype: int64
# osm_id     count    23
# timestamp  count     0
# name       count    22
# geometry   count    23
# Name: (401011001, bar), dtype: int64
# osm_id     count    32
# timestamp  count     0
# name       count     0
# geometry   count    32
# Name: (401011001, bbq), dtype: int64
# osm_id     count    1205
# timestamp  count       0
# name       count       0
# geometry   count    1205
# Name: (401011001, bench), dtype: int64
# osm_id     count    407
# timestamp  count      0
# name       count      0
# geometry   count    407
# Name: (401011001, bicycle_parking), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    5
# geometry   count    5
# Name: (401011001, bicycle_rental), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011001, bicycle_repair_s), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011001, buffer_stop), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, bureau_de_change), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011001, bus_station), dtype: int64
# osm_id     count    215
# timestamp  count      0
# name       count    211
# geometry   count    215
# Name: (401011001, bus_stop), dtype: int64
# osm_id     count    104
# timestamp  count      0
# name       count     99
# geometry   count    104
# Name: (401011001, cafe), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401011001, car_rental), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011001, charging_station), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, childcare), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401011001, cinema), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    5
# geometry   count    5
# Name: (401011001, clinic), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, college), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, community_centre), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011001, construction), dtype: int64
# osm_id     count    380
# timestamp  count      0
# name       count      0
# geometry   count    380
# Name: (401011001, crossing), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    3
# geometry   count    4
# Name: (401011001, dentist), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011001, device_charging_), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, doctors), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, dojo), dtype: int64
# osm_id     count    85
# timestamp  count     0
# name       count     1
# geometry   count    85
# Name: (401011001, drinking_water), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, embassy), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, events_venue), dtype: int64
# osm_id     count    73
# timestamp  count     0
# name       count    68
# geometry   count    73
# Name: (401011001, fast_food), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    1
# geometry   count    4
# Name: (401011001, food_court), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    0
# geometry   count    5
# Name: (401011001, fountain), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    4
# geometry   count    5
# Name: (401011001, fuel), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011001, give_way), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, guest_house;hote), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    6
# geometry   count    6
# Name: (401011001, hostel), dtype: int64
# osm_id     count    14
# timestamp  count     0
# name       count    14
# geometry   count    14
# Name: (401011001, hotel), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401011001, ice_cream), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    2
# geometry   count    5
# Name: (401011001, information), dtype: int64
# osm_id     count    92
# timestamp  count     0
# name       count     0
# geometry   count    92
# Name: (401011001, level_crossing), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401011001, library), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    5
# geometry   count    7
# Name: (401011001, memorial), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, monitoring_stati), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011001, monument), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, motel), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    4
# geometry   count    4
# Name: (401011001, museum), dtype: int64
# osm_id     count    10
# timestamp  count     0
# name       count    10
# geometry   count    10
# Name: (401011001, nightclub), dtype: int64
# osm_id     count    19
# timestamp  count     0
# name       count     6
# geometry   count    19
# Name: (401011001, parking), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011001, parking_entrance), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011001, parking_space), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    5
# geometry   count    7
# Name: (401011001, pharmacy), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    9
# geometry   count    9
# Name: (401011001, place_of_worship), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401011001, police), dtype: int64
# osm_id     count    14
# timestamp  count     0
# name       count     0
# geometry   count    14
# Name: (401011001, post_box), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    3
# geometry   count    5
# Name: (401011001, post_office), dtype: int64
# osm_id     count    36
# timestamp  count     0
# name       count    35
# geometry   count    36
# Name: (401011001, pub), dtype: int64
# osm_id     count    124
# timestamp  count      0
# name       count    119
# geometry   count    124
# Name: (401011001, restaurant), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, restaurant;bar), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401011001, school), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, shelter), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, social_facility), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401011001, speed_camera), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401011001, station), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011001, steps), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, stripclub), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, studio), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, subway_entrance), dtype: int64
# osm_id     count    16
# timestamp  count     0
# name       count     0
# geometry   count    16
# Name: (401011001, surveillance), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011001, survey_point), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401011001, taxi), dtype: int64
# osm_id     count    11
# timestamp  count     0
# name       count     0
# geometry   count    11
# Name: (401011001, telephone), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    6
# geometry   count    6
# Name: (401011001, theatre), dtype: int64
# osm_id     count    27
# timestamp  count     0
# name       count     2
# geometry   count    27
# Name: (401011001, toilets), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011001, tower), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011001, townhall), dtype: int64
# osm_id     count    155
# timestamp  count      0
# name       count      0
# geometry   count    155
# Name: (401011001, traffic_signals), dtype: int64
# osm_id     count    29
# timestamp  count     0
# name       count    29
# geometry   count    29
# Name: (401011001, tram_stop), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401011001, turning_circle), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    0
# geometry   count    9
# Name: (401011001, vending_machine), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    1
# geometry   count    3
# Name: (401011001, viewpoint), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    0
# geometry   count    5
# Name: (401011001, waste_basket), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401011002, artwork), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    2
# geometry   count    3
# Name: (401011002, attraction), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401011002, bank), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    3
# geometry   count    4
# Name: (401011002, bar), dtype: int64
# osm_id     count    13
# timestamp  count     0
# name       count     0
# geometry   count    13
# Name: (401011002, bbq), dtype: int64
# osm_id     count    346
# timestamp  count      0
# name       count      0
# geometry   count    346
# Name: (401011002, bench), dtype: int64
# osm_id     count    60
# timestamp  count     0
# name       count     0
# geometry   count    60
# Name: (401011002, bicycle_parking), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401011002, bicycle_rental), dtype: int64
# osm_id     count    61
# timestamp  count     0
# name       count    61
# geometry   count    61
# Name: (401011002, bus_stop), dtype: int64
# osm_id     count    13
# timestamp  count     0
# name       count    12
# geometry   count    13
# Name: (401011002, cafe), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011002, clock), dtype: int64
# osm_id     count    39
# timestamp  count     0
# name       count     0
# geometry   count    39
# Name: (401011002, crossing), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    1
# geometry   count    2
# Name: (401011002, dentist), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011002, doctors), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011002, dojo), dtype: int64
# osm_id     count    43
# timestamp  count     0
# name       count     0
# geometry   count    43
# Name: (401011002, drinking_water), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    5
# geometry   count    5
# Name: (401011002, fast_food), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011002, fountain), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, fuel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011002, give_way), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, hospital), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, hotel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011002, information), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, kindergarten), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011002, level_crossing), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    2
# geometry   count    5
# Name: (401011002, memorial), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    1
# geometry   count    2
# Name: (401011002, monument), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, parking), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011002, parking_entrance), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, pharmacy), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    0
# geometry   count    5
# Name: (401011002, picnic_site), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401011002, post_box), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, post_office), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401011002, pub), dtype: int64
# osm_id     count    30
# timestamp  count     0
# name       count    29
# geometry   count    30
# Name: (401011002, restaurant), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, school), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011002, shelter), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011002, speed_camera), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, station), dtype: int64
# osm_id     count    8
# timestamp  count    0
# name       count    0
# geometry   count    8
# Name: (401011002, street_lamp), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401011002, surveillance), dtype: int64
# osm_id     count    17
# timestamp  count     0
# name       count    17
# geometry   count    17
# Name: (401011002, survey_point), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401011002, toilets), dtype: int64
# osm_id     count    45
# timestamp  count     0
# name       count     0
# geometry   count    45
# Name: (401011002, traffic_signals), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    0
# geometry   count    9
# Name: (401011002, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401011002, viewpoint), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401011002, waste_basket), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401021004, artwork), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401021004, atm), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, attraction), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    4
# geometry   count    4
# Name: (401021004, bank), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021004, bbq), dtype: int64
# osm_id     count    14
# timestamp  count     0
# name       count     1
# geometry   count    14
# Name: (401021004, bench), dtype: int64
# osm_id     count    113
# timestamp  count      0
# name       count    113
# geometry   count    113
# Name: (401021004, bus_stop), dtype: int64
# osm_id     count    10
# timestamp  count     0
# name       count    10
# geometry   count    10
# Name: (401021004, cafe), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, clinic), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401021004, crossing), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401021004, dentist), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, doctors), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021004, drinking_water), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    6
# geometry   count    6
# Name: (401021004, fast_food), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    1
# geometry   count    2
# Name: (401021004, fuel), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401021004, hotel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, information), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, kindergarten), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021004, level_crossing), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021004, memorial), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401021004, monument), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    2
# geometry   count    5
# Name: (401021004, motorway_junctio), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, museum), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401021004, parking), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401021004, pharmacy), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401021004, place_of_worship), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, police), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    0
# geometry   count    5
# Name: (401021004, post_box), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    2
# geometry   count    3
# Name: (401021004, post_office), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401021004, pub), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, recycling), dtype: int64
# osm_id     count    11
# timestamp  count     0
# name       count    11
# geometry   count    11
# Name: (401021004, restaurant), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401021004, ruins), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401021004, school), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401021004, shelter), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021004, speed_camera), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401021004, telephone), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, theatre), dtype: int64
# osm_id     count    10
# timestamp  count     0
# name       count     0
# geometry   count    10
# Name: (401021004, toilets), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    1
# geometry   count    7
# Name: (401021004, tower), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021004, traffic_signals), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021004, trailhead), dtype: int64
# osm_id     count    30
# timestamp  count     0
# name       count     0
# geometry   count    30
# Name: (401021004, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021004, veterinary), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021004, viewpoint), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, artwork), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    1
# geometry   count    2
# Name: (401021010, attraction), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, bbq), dtype: int64
# osm_id     count    21
# timestamp  count     0
# name       count     1
# geometry   count    21
# Name: (401021010, bench), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401021010, bicycle_parking), dtype: int64
# osm_id     count    33
# timestamp  count     0
# name       count    33
# geometry   count    33
# Name: (401021010, bus_stop), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401021010, cafe), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, charging_station), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, communications_t), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, crossing), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    0
# geometry   count    5
# Name: (401021010, drinking_water), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, give_way), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021010, hostel), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    2
# geometry   count    3
# Name: (401021010, information), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021010, place_of_worship), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401021010, post_box), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401021010, post_office), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021010, pub), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, public_bookcase), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401021010, restaurant), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    5
# geometry   count    7
# Name: (401021010, ruins), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401021010, stop), dtype: int64
# osm_id     count    12
# timestamp  count     0
# name       count     0
# geometry   count    12
# Name: (401021010, storage_tank), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, surveillance), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, survey_point), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, tank), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401021010, toilets), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    1
# geometry   count    5
# Name: (401021010, tower), dtype: int64
# osm_id     count    21
# timestamp  count     0
# name       count     0
# geometry   count    21
# Name: (401021010, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401021010, turning_loop), dtype: int64
# osm_id     count    12
# timestamp  count     0
# name       count     7
# geometry   count    12
# Name: (401021010, viewpoint), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401021010, water_tank), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401031011, adit), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, artwork), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, atm), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, bbq), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, bench), dtype: int64
# osm_id     count    23
# timestamp  count     0
# name       count     0
# geometry   count    23
# Name: (401031011, bicycle_parking), dtype: int64
# osm_id     count    96
# timestamp  count     0
# name       count    96
# geometry   count    96
# Name: (401031011, bus_stop), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    8
# geometry   count    9
# Name: (401031011, cafe), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031011, cinema), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    7
# geometry   count    7
# Name: (401031011, clinic), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031011, community_centre), dtype: int64
# osm_id     count    18
# timestamp  count     0
# name       count     0
# geometry   count    18
# Name: (401031011, crossing), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    2
# geometry   count    3
# Name: (401031011, dentist), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, doctors), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401031011, drinking_water), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    3
# geometry   count    4
# Name: (401031011, fast_food), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, give_way), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, grave_yard), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031011, guest_house), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401031011, parking), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401031011, pharmacy), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    4
# geometry   count    4
# Name: (401031011, place_of_worship), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    0
# geometry   count    7
# Name: (401031011, post_box), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    3
# geometry   count    4
# Name: (401031011, post_office), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031011, pub), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, public_bookcase), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    9
# geometry   count    9
# Name: (401031011, restaurant), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031011, school), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401031011, telephone), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401031011, toilets), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    0
# geometry   count    9
# Name: (401031011, traffic_signals), dtype: int64
# osm_id     count    46
# timestamp  count     0
# name       count     0
# geometry   count    46
# Name: (401031011, turning_circle), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401031011, turning_loop), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031011, vending_machine), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031011, veterinary), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031011, viewpoint), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, adit), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, animal_boarding), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, artwork), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401031012, atm), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401031012, attraction), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    0
# geometry   count    6
# Name: (401031012, bench), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    2
# geometry   count    5
# Name: (401031012, bicycle_parking), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, bicycle_repair_s), dtype: int64
# osm_id     count    40
# timestamp  count     0
# name       count    39
# geometry   count    40
# Name: (401031012, bus_stop), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    2
# geometry   count    3
# Name: (401031012, cafe), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, compressed_air), dtype: int64
# osm_id     count    14
# timestamp  count     0
# name       count     0
# geometry   count    14
# Name: (401031012, crossing), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, dentist), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, doctors), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, drinking_water), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    4
# geometry   count    4
# Name: (401031012, fast_food), dtype: int64
# osm_id     count    8
# timestamp  count    0
# name       count    7
# geometry   count    8
# Name: (401031012, information), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, kindergarten), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, mast), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, mine_shaft), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, monument), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401031012, parking_entrance), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401031012, pharmacy), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401031012, place_of_worship), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    1
# geometry   count    3
# Name: (401031012, post_box), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, post_office), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, rest_area), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    4
# geometry   count    4
# Name: (401031012, restaurant), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401031012, ruins), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, school), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, stop), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031012, telephone), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401031012, toilets), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, tower), dtype: int64
# osm_id     count    8
# timestamp  count    0
# name       count    0
# geometry   count    8
# Name: (401031012, traffic_signals), dtype: int64
# osm_id     count    28
# timestamp  count     0
# name       count     0
# geometry   count    28
# Name: (401031012, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031012, viewpoint), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031013, bank), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031013, bbq), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031013, bench), dtype: int64
# osm_id     count    14
# timestamp  count     0
# name       count     0
# geometry   count    14
# Name: (401031013, bicycle_parking), dtype: int64
# osm_id     count    103
# timestamp  count      0
# name       count    103
# geometry   count    103
# Name: (401031013, bus_stop), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    8
# geometry   count    9
# Name: (401031013, cafe), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    4
# geometry   count    4
# Name: (401031013, clinic), dtype: int64
# osm_id     count    32
# timestamp  count     0
# name       count     0
# geometry   count    32
# Name: (401031013, crossing), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031013, dentist), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    1
# geometry   count    2
# Name: (401031013, doctors), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401031013, drinking_water), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    6
# geometry   count    6
# Name: (401031013, fast_food), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031013, fuel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031013, ice_cream), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031013, information), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401031013, library), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401031013, parking), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    6
# geometry   count    6
# Name: (401031013, pharmacy), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    2
# geometry   count    3
# Name: (401031013, place_of_worship), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    3
# geometry   count    6
# Name: (401031013, post_box), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031013, post_office), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    5
# geometry   count    6
# Name: (401031013, restaurant), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401031013, stop), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031013, taxi), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    1
# geometry   count    4
# Name: (401031013, toilets), dtype: int64
# osm_id     count    13
# timestamp  count     0
# name       count     0
# geometry   count    13
# Name: (401031013, traffic_signals), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    0
# geometry   count    9
# Name: (401031013, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401031013, waste_basket), dtype: int64
# osm_id     count    43
# timestamp  count     0
# name       count    43
# geometry   count    43
# Name: (401041014, bus_stop), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401041014, crossing), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041014, parking), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401041014, post_box), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041014, telephone), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041014, toilets), dtype: int64
# osm_id     count    67
# timestamp  count     0
# name       count     0
# geometry   count    67
# Name: (401041014, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041015, artwork), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401041015, bank), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401041015, bicycle_parking), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401041015, bus_station), dtype: int64
# osm_id     count    116
# timestamp  count      0
# name       count    116
# geometry   count    116
# Name: (401041015, bus_stop), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401041015, cafe), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041015, community_centre), dtype: int64
# osm_id     count    95
# timestamp  count     0
# name       count     0
# geometry   count    95
# Name: (401041015, crossing), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041015, doctors), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041015, drinking_water), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    4
# geometry   count    4
# Name: (401041015, fast_food), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401041015, fuel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041015, hospital), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    1
# geometry   count    3
# Name: (401041015, pharmacy), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401041015, post_box), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041015, public_bookcase), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401041015, restaurant), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (401041015, school), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041015, shelter), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401041015, speed_camera), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041015, toilets), dtype: int64
# osm_id     count    30
# timestamp  count     0
# name       count     0
# geometry   count    30
# Name: (401041015, traffic_signals), dtype: int64
# osm_id     count    65
# timestamp  count     0
# name       count     0
# geometry   count    65
# Name: (401041015, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041016, bbq), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401041016, bench), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (401041016, bicycle_parking), dtype: int64
# osm_id     count    95
# timestamp  count     0
# name       count    95
# geometry   count    95
# Name: (401041016, bus_stop), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401041016, cafe), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041016, car_wash), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    4
# geometry   count    4
# Name: (401041016, clinic), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041016, clock), dtype: int64
# osm_id     count    34
# timestamp  count     0
# name       count     0
# geometry   count    34
# Name: (401041016, crossing), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041016, dentist), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041016, doctors), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (401041016, drinking_water), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (401041016, fast_food), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    2
# geometry   count    3
# Name: (401041016, fuel), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (401041016, give_way), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041016, mast), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041016, memorial), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041016, pharmacy), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    1
# geometry   count    2
# Name: (401041016, picnic_site), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041016, place_of_worship), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (401041016, post_box), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041016, post_office), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (401041016, recycling), dtype: int64
# osm_id     count    8
# timestamp  count    0
# name       count    6
# geometry   count    8
# Name: (401041016, restaurant), dtype: int64
# osm_id     count    2
# ...
# Name: (404031104, vending_machine), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031105, bank), dtype: int64
# osm_id     count    11
# timestamp  count     0
# name       count    11
# geometry   count    11
# Name: (404031105, bus_stop), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031105, cafe), dtype: int64
# osm_id     count    11
# timestamp  count     0
# name       count     0
# geometry   count    11
# Name: (404031105, crossing), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031105, doctors), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031105, drinking_water), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (404031105, fast_food), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031105, hotel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031105, restaurant), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031105, speed_camera), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031105, telephone), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (404031105, traffic_signals), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    0
# geometry   count    6
# Name: (404031105, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031105, turning_loop), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031106, atm), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031106, bank), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031106, bench), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031106, bicycle_repair_s), dtype: int64
# osm_id     count    58
# timestamp  count     0
# name       count    58
# geometry   count    58
# Name: (404031106, bus_stop), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031106, cafe), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031106, car_rental), dtype: int64
# osm_id     count    13
# timestamp  count     0
# name       count     0
# geometry   count    13
# Name: (404031106, crossing), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (404031106, drinking_water), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    3
# geometry   count    5
# Name: (404031106, fast_food), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031106, fuel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031106, motel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031106, place_of_worship), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031106, post_box), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031106, restaurant), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031106, shelter), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (404031106, survey_point), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031106, toilets), dtype: int64
# osm_id     count    19
# timestamp  count     0
# name       count     0
# geometry   count    19
# Name: (404031106, traffic_signals), dtype: int64
# osm_id     count    11
# timestamp  count     0
# name       count     0
# geometry   count    11
# Name: (404031106, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031106, waste_basket), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031107, Historical_House), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031107, bar), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031107, bicycle_repair_s), dtype: int64
# osm_id     count    150
# timestamp  count      0
# name       count    150
# geometry   count    150
# Name: (404031107, bus_stop), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    5
# geometry   count    5
# Name: (404031107, cafe), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031107, car_rental), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031107, car_wash), dtype: int64
# osm_id     count    73
# timestamp  count     0
# name       count     1
# geometry   count    73
# Name: (404031107, crossing), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (404031107, drinking_water), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    7
# geometry   count    7
# Name: (404031107, fast_food), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031107, flagpole), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031107, fuel), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031107, halt), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031107, hospital), dtype: int64
# osm_id     count    10
# timestamp  count     0
# name       count     0
# geometry   count    10
# Name: (404031107, level_crossing), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031107, motorway_junctio), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031107, parking), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (404031107, pharmacy), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031107, police), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    0
# geometry   count    5
# Name: (404031107, post_box), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031107, post_office), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031107, restaurant), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031107, school), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031107, shelter), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031107, speed_camera), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031107, telephone), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (404031107, toilets), dtype: int64
# osm_id     count    36
# timestamp  count     0
# name       count     0
# geometry   count    36
# Name: (404031107, traffic_signals), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    7
# geometry   count    7
# Name: (404031107, tram_stop), dtype: int64
# osm_id     count    25
# timestamp  count     0
# name       count     0
# geometry   count    25
# Name: (404031107, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031107, waste_basket), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031108, apartment), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, artwork), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031108, atm), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031108, bank), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031108, bar), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, bbq), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (404031108, bench), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    0
# geometry   count    5
# Name: (404031108, bicycle_parking), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, buffer_stop), dtype: int64
# osm_id     count    97
# timestamp  count     0
# name       count    97
# geometry   count    97
# Name: (404031108, bus_stop), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    8
# geometry   count    9
# Name: (404031108, cafe), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (404031108, car_rental), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031108, childcare), dtype: int64
# osm_id     count    91
# timestamp  count     0
# name       count     0
# geometry   count    91
# Name: (404031108, crossing), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031108, doctors), dtype: int64
# osm_id     count    7
# timestamp  count    0
# name       count    1
# geometry   count    7
# Name: (404031108, drinking_water), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (404031108, fast_food), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    3
# geometry   count    4
# Name: (404031108, fuel), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, give_way), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031108, level_crossing), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031108, memorial), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031108, pharmacy), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, picnic_site), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    2
# geometry   count    3
# Name: (404031108, place_of_worship), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, post_box), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031108, post_office), dtype: int64
# osm_id     count    5
# timestamp  count    0
# name       count    4
# geometry   count    5
# Name: (404031108, pub), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (404031108, recycling), dtype: int64
# osm_id     count    9
# timestamp  count    0
# name       count    7
# geometry   count    9
# Name: (404031108, restaurant), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, shelter), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031108, speed_camera), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031108, station), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, street_lamp), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, taxi), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031108, telephone), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, toilets), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031108, townhall), dtype: int64
# osm_id     count    45
# timestamp  count     0
# name       count     0
# geometry   count    45
# Name: (404031108, traffic_signals), dtype: int64
# osm_id     count    11
# timestamp  count     0
# name       count     0
# geometry   count    11
# Name: (404031108, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031108, vending_machine), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    0
# geometry   count    3
# Name: (404031108, waste_basket), dtype: int64
# osm_id     count    10
# timestamp  count     0
# name       count     0
# geometry   count    10
# Name: (404031109, bench), dtype: int64
# osm_id     count    47
# timestamp  count     0
# name       count    47
# geometry   count    47
# Name: (404031109, bus_stop), dtype: int64
# osm_id     count    3
# timestamp  count    0
# name       count    3
# geometry   count    3
# Name: (404031109, cafe), dtype: int64
# osm_id     count    53
# timestamp  count     0
# name       count     0
# geometry   count    53
# Name: (404031109, crossing), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    0
# geometry   count    2
# Name: (404031109, drinking_water), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    1
# geometry   count    1
# Name: (404031109, restaurant), dtype: int64
# osm_id     count    6
# timestamp  count    0
# name       count    0
# geometry   count    6
# Name: (404031109, shelter), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031109, shower), dtype: int64
# osm_id     count    2
# timestamp  count    0
# name       count    2
# geometry   count    2
# Name: (404031109, survey_point), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031109, toilets), dtype: int64
# osm_id     count    4
# timestamp  count    0
# name       count    0
# geometry   count    4
# Name: (404031109, traffic_signals), dtype: int64
# osm_id     count    10
# timestamp  count     0
# name       count     0
# geometry   count    10
# Name: (404031109, turning_circle), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031109, vending_machine), dtype: int64
# osm_id     count    1
# timestamp  count    0
# name       count    0
# geometry   count    1
# Name: (404031109, viewpoint), dtype: int64

# %%
poi_df = pd.DataFrame()

# %%
poi_df["SA2_MAIN16"] = count.index.values
poi_df["poi_count"] = count[( 'geometry', 'count')].values

# %%
poi_df.head()
# Out:
#   SA2_MAIN16  poi_count
# 0  401011001       3288
# 1  401011002        756
# 2  401021004        279
# 3  401021010        153
# 4  401031011        276

# %%
split_count.shape
# Out:
# (1799, 4)

# %%
import math

# %%
entropy = {}
for i, row in split_count.iterrows():
    sa_id, _type = i
    total_count = poi_df.loc[poi_df["SA2_MAIN16"]==sa_id]["poi_count"]
    val = row[( 'geometry', 'count')]/total_count
    
    if sa_id not in entropy:
        entropy[sa_id] = (-val * np.log(val))
    else:
        entropy[sa_id] += (-val * np.log(val))

# %%
# entropy
# Out:
# {'401011001': 0    2.487969
#  Name: poi_count, dtype: float64,
#  '401011002': 1    2.246419
#  Name: poi_count, dtype: float64,
#  '401021004': 2    2.616117
#  Name: poi_count, dtype: float64,
#  '401021010': 3    2.722838
#  Name: poi_count, dtype: float64,
#  '401031011': 4    2.472982
#  Name: poi_count, dtype: float64,
#  '401031012': 5    2.777293
#  Name: poi_count, dtype: float64,
#  '401031013': 6    2.212926
#  Name: poi_count, dtype: float64,
#  '401041014': 7    0.94834
#  Name: poi_count, dtype: float64,
#  '401041015': 8    1.76826
#  Name: poi_count, dtype: float64,
#  '401041016': 9    2.111002
#  Name: poi_count, dtype: float64,
#  '401051017': 10    2.670116
#  Name: poi_count, dtype: float64,
#  '401051018': 11    2.127715
#  Name: poi_count, dtype: float64,
#  '401051019': 12    2.203846
#  Name: poi_count, dtype: float64,
#  '401061020': 13    1.828527
#  Name: poi_count, dtype: float64,
#  '401061021': 14    2.515008
#  Name: poi_count, dtype: float64,
#  '401061022': 15    2.236807
#  Name: poi_count, dtype: float64,
#  '401071023': 16    2.50107
#  Name: poi_count, dtype: float64,
#  '401071024': 17    2.36401
#  Name: poi_count, dtype: float64,
#  '402021030': 18    1.368212
#  Name: poi_count, dtype: float64,
#  '402021031': 19    1.309526
#  Name: poi_count, dtype: float64,
#  '402021033': 20   -0.0
#  Name: poi_count, dtype: float64,
#  '402031036': 21    1.961201
#  Name: poi_count, dtype: float64,
#  '402031037': 22    1.662138
#  Name: poi_count, dtype: float64,
#  '402031038': 23    1.605421
#  Name: poi_count, dtype: float64,
#  '402041039': 24    1.456389
#  Name: poi_count, dtype: float64,
#  '402041040': 25    1.444396
#  Name: poi_count, dtype: float64,
#  '402041041': 26    1.419602
#  Name: poi_count, dtype: float64,
#  '402041042': 27    1.800796
#  Name: poi_count, dtype: float64,
#  '402041043': 28    1.210667
#  Name: poi_count, dtype: float64,
#  '402041044': 29    1.252866
#  Name: poi_count, dtype: float64,
#  '402041046': 30    2.001965
#  Name: poi_count, dtype: float64,
#  '402041047': 31    1.798977
#  Name: poi_count, dtype: float64,
#  '402041048': 32    1.773518
#  Name: poi_count, dtype: float64,
#  '402041171': 33    2.173789
#  Name: poi_count, dtype: float64,
#  '402041172': 34    1.462005
#  Name: poi_count, dtype: float64,
#  '402051049': 35    1.573617
#  Name: poi_count, dtype: float64,
#  '402051050': 36    1.144179
#  Name: poi_count, dtype: float64,
#  '402051051': 37    1.68355
#  Name: poi_count, dtype: float64,
#  '402051052': 38    1.726459
#  Name: poi_count, dtype: float64,
#  '402051053': 39    1.345204
#  Name: poi_count, dtype: float64,
#  '402051054': 40    1.332073
#  Name: poi_count, dtype: float64,
#  '402051055': 41    1.783884
#  Name: poi_count, dtype: float64,
#  '403011056': 42    2.664831
#  Name: poi_count, dtype: float64,
#  '403011057': 43    2.691052
#  Name: poi_count, dtype: float64,
#  '403021058': 44    1.966363
#  Name: poi_count, dtype: float64,
#  '403021060': 45    1.868863
#  Name: poi_count, dtype: float64,
#  '403021061': 46    2.054419
#  Name: poi_count, dtype: float64,
#  '403021062': 47    1.635342
#  Name: poi_count, dtype: float64,
#  '403021064': 48    2.006946
#  Name: poi_count, dtype: float64,
#  '403031065': 49    2.522405
#  Name: poi_count, dtype: float64,
#  '403031066': 50    1.984739
#  Name: poi_count, dtype: float64,
#  '403031067': 51    1.878335
#  Name: poi_count, dtype: float64,
#  '403031068': 52    1.944075
#  Name: poi_count, dtype: float64,
#  '403031069': 53    2.25414
#  Name: poi_count, dtype: float64,
#  '403031070': 54    1.771559
#  Name: poi_count, dtype: float64,
#  '403041077': 55    1.479848
#  Name: poi_count, dtype: float64,
#  '404011090': 56    2.245418
#  Name: poi_count, dtype: float64,
#  '404011091': 57    1.90718
#  Name: poi_count, dtype: float64,
#  '404011092': 58    2.210565
#  Name: poi_count, dtype: float64,
#  '404011093': 59    2.792972
#  Name: poi_count, dtype: float64,
#  '404011094': 60    1.808827
#  Name: poi_count, dtype: float64,
#  '404011095': 61    2.817612
#  Name: poi_count, dtype: float64,
#  '404011096': 62    2.48591
#  Name: poi_count, dtype: float64,
#  '404011097': 63    2.529995
#  Name: poi_count, dtype: float64,
#  '404021098': 64    1.039721
#  Name: poi_count, dtype: float64,
#  '404021099': 65    2.801267
#  Name: poi_count, dtype: float64,
#  '404021100': 66    2.167064
#  Name: poi_count, dtype: float64,
#  '404021101': 67    2.968548
#  Name: poi_count, dtype: float64,
#  '404021102': 68    2.307954
#  Name: poi_count, dtype: float64,
#  '404021103': 69    1.098612
#  Name: poi_count, dtype: float64,
#  '404031104': 70    2.637443
#  Name: poi_count, dtype: float64,
#  '404031105': 71    2.139979
#  Name: poi_count, dtype: float64,
#  '404031106': 72    1.991836
#  Name: poi_count, dtype: float64,
#  '404031107': 73    2.01312
#  Name: poi_count, dtype: float64,
#  '404031108': 74    2.342724
#  Name: poi_count, dtype: float64,
#  '404031109': 75    1.717811
#  Name: poi_count, dtype: float64}

# %%
print(len(entropy))
print(len(poi_df))
# Out:
# 76
# 76

# %%
entropy_list = []
for sa_id in poi_df.SA2_MAIN16:
    entropy_list.append(float(entropy[sa_id]))

# %%
poi_df["poi_count_entropy"] = entropy_list

# %%
poi_df.head()
# Out:
#   SA2_MAIN16  poi_count  poi_count_entropy
# 0  401011001       3288           2.487969
# 1  401011002        756           2.246419
# 2  401021004        279           2.616117
# 3  401021010        153           2.722838
# 4  401031011        276           2.472982

# %%
# plt.hist(poi_df.poi_count_entropy)
# Out:
# (array([ 1.,  0.,  0.,  4., 11., 10., 17., 15., 11.,  7.]),
#  array([0.        , 0.29685483, 0.59370966, 0.8905645 , 1.18741933,
#         1.48427416, 1.78112899, 2.07798383, 2.37483866, 2.67169349,
#         2.96854832]),
#  <a list of 10 Patch objects>)

# %%
node_degree_entropy_df = node_degree_df.merge(poi_df,how="left",on="SA2_MAIN16")

# %%
node_degree_entropy_df.head()
# Out:
#   SA2_MAIN16 SA2_5DIG16          SA2_NAME16 SA3_CODE16      SA3_NAME16  \
# 0  401011001      41001            Adelaide      40101   Adelaide City
# 1  401011002      41002      North Adelaide      40101   Adelaide City
# 2  401021003      41003      Adelaide Hills      40102  Adelaide Hills
# 3  401021004      41004  Aldgate - Stirling      40102  Adelaide Hills
# 4  401021005      41005  Hahndorf - Echunga      40102  Adelaide Hills
#
#   SA4_CODE16                    SA4_NAME16 GCC_CODE16        GCC_NAME16  \
# 0        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 1        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 2        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 3        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 4        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
#
#   STE_CODE16  ... sum_stay_duration_destination_entropy  \
# 0          4  ...                              3.949646
# 1          4  ...                              3.152188
# 2          4  ...                              0.948900
# 3          4  ...                              1.099284
# 4          4  ...                              1.654530
#
#    total_stays_destination_entropy  num_nodes  num_1degree  num_2degree  \
# 0                         4.237396       1642          291          199
# 1                         3.975034        517          149           54
# 2                         2.042530       4034         1174          731
# 3                         2.075796       2455          710          502
# 4                         2.549629        989          286          245
#
#    num_3degree  num_4degree  num_greater5degree  poi_count  poi_count_entropy
# 0          865          276                  11     3288.0           2.487969
# 1          239           69                   6      756.0           2.246419
# 2         1982          141                   6        NaN                NaN
# 3         1126          110                   7      279.0           2.616117
# 4          421           36                   1        NaN                NaN
#
# [5 rows x 50 columns]

# %%
# sw - editting poi_count and poit_count_entropy - replacing NaN by zeros
node_degree_entropy_df.loc[node_degree_entropy_df.poi_count.isna(), 'poi_count'] = 0.0 
node_degree_entropy_df.loc[node_degree_entropy_df.poi_count_entropy.isna(), 'poi_count_entropy'] = 0.0

# %%
node_degree_entropy_df
# Out:
#     SA2_MAIN16 SA2_5DIG16          SA2_NAME16 SA3_CODE16      SA3_NAME16  \
# 0    401011001      41001            Adelaide      40101   Adelaide City
# 1    401011002      41002      North Adelaide      40101   Adelaide City
# 2    401021003      41003      Adelaide Hills      40102  Adelaide Hills
# 3    401021004      41004  Aldgate - Stirling      40102  Adelaide Hills
# 4    401021005      41005  Hahndorf - Echunga      40102  Adelaide Hills
# ..         ...        ...                 ...        ...             ...
# 98   404031105      41105              Fulham      40403    West Torrens
# 99   404031106      41106            Lockleys      40403    West Torrens
# 100  404031107      41107            Plympton      40403    West Torrens
# 101  404031108      41108       Richmond (SA)      40403    West Torrens
# 102  404031109      41109          West Beach      40403    West Torrens
#
#     SA4_CODE16                    SA4_NAME16 GCC_CODE16        GCC_NAME16  \
# 0          401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 1          401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 2          401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 3          401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 4          401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# ..         ...                           ...        ...               ...
# 98         404               Adelaide - West      4GADE  Greater Adelaide
# 99         404               Adelaide - West      4GADE  Greater Adelaide
# 100        404               Adelaide - West      4GADE  Greater Adelaide
# 101        404               Adelaide - West      4GADE  Greater Adelaide
# 102        404               Adelaide - West      4GADE  Greater Adelaide
#
#     STE_CODE16  ... sum_stay_duration_destination_entropy  \
# 0            4  ...                              3.949646
# 1            4  ...                              3.152188
# 2            4  ...                              0.948900
# 3            4  ...                              1.099284
# 4            4  ...                              1.654530
# ..         ...  ...                                   ...
# 98           4  ...                              1.975506
# 99           4  ...                              1.416921
# 100          4  ...                              1.695853
# 101          4  ...                              2.308701
# 102          4  ...                              1.752475
#
#      total_stays_destination_entropy  num_nodes  num_1degree  num_2degree  \
# 0                           4.237396       1642          291          199
# 1                           3.975034        517          149           54
# 2                           2.042530       4034         1174          731
# 3                           2.075796       2455          710          502
# 4                           2.549629        989          286          245
# ..                               ...        ...          ...          ...
# 98                          2.784143        157           28           19
# 99                          2.608267        530          102           39
# 100                         2.732940       1036          170          105
# 101                         3.390496        887          125          120
# 102                         3.175361        228           37           20
#
#      num_3degree  num_4degree  num_greater5degree  poi_count  \
# 0            865          276                  11     3288.0
# 1            239           69                   6      756.0
# 2           1982          141                   6        0.0
# 3           1126          110                   7      279.0
# 4            421           36                   1        0.0
# ..           ...          ...                 ...        ...
# 98            90           20                   0       44.0
# 99           308           81                   0      129.0
# 100          616          143                   2      353.0
# 101          410          231                   1      334.0
# 102          151           19                   1      142.0
#
#      poi_count_entropy
# 0             2.487969
# 1             2.246419
# 2             0.000000
# 3             2.616117
# 4             0.000000
# ..                 ...
# 98            2.139979
# 99            1.991836
# 100           2.013120
# 101           2.342724
# 102           1.717811
#
# [103 rows x 50 columns]

# %%
node_degree_df.shape
# Out:
# (103, 48)

# %%
node_degree_entropy_df.shape
# Out:
# (103, 50)

# %%
node_degree_entropy_df.to_pickle('../../data_process/node_degree_entropy_df.pickle')

# %% [markdown]
# # Edge Degree DF

# %%
edge_degree_df.head()
# Out:
#                        timestamp destination  state     origin  unique_agents  \
# 0  2018-02-01T00:00:00.000+11:00   401011001      4  401011001          19863
# 1  2018-02-01T00:00:00.000+11:00   401011002      4  401011001           6911
# 2  2018-02-01T00:00:00.000+11:00   401021003      4  401011001            404
# 3  2018-02-01T00:00:00.000+11:00   401021004      4  401011001           1184
# 4  2018-02-01T00:00:00.000+11:00   401021005      4  401011001            700
#
#    sum_stay_duration  total_stays                  OD  class_ART  class_BUS  \
# 0          268779414       681217  401011001401011001      208.0       13.0
# 1            4857456        29322  401011001401011002      267.0       16.0
# 2             253764         1334  401011001401021003      838.0       82.0
# 3             903377         5487  401011001401021004      430.0       13.0
# 4             189721         1278  401011001401021005      517.0       13.0
#
#    ...  num_2degree_x  num_3degree_x  num_4degree_x  num_greater5degree_x  \
# 0  ...          199.0          865.0          276.0                  11.0
# 1  ...          199.0          865.0          276.0                  11.0
# 2  ...          199.0          865.0          276.0                  11.0
# 3  ...          199.0          865.0          276.0                  11.0
# 4  ...          199.0          865.0          276.0                  11.0
#
#    num_nodes_y  num_1degree_y  num_2degree_y  num_3degree_y  num_4degree_y  \
# 0       1642.0          291.0          199.0          865.0          276.0
# 1        517.0          149.0           54.0          239.0           69.0
# 2       4034.0         1174.0          731.0         1982.0          141.0
# 3       2455.0          710.0          502.0         1126.0          110.0
# 4        989.0          286.0          245.0          421.0           36.0
#
#   num_greater5degree_y
# 0                 11.0
# 1                  6.0
# 2                  6.0
# 3                  7.0
# 4                  1.0
#
# [5 rows x 39 columns]

# %%
entropy_x = []
notin = 0
for sa_id in edge_degree_df["sa2_code16_x"].values:
    if sa_id in entropy:
        entropy_x.append(float(entropy[sa_id]))
    else:
        notin += 1
print(notin)
notin=0
entropy_y = []
for sa_id in edge_degree_df["sa2_code16_y"]:
    if sa_id in entropy:
        entropy_y.append(float(entropy[sa_id]))
    else:
        notin += 1
print(notin)
# Out:
# 3065
# 3122

# %%
notin
# Out:
# 3122

# %%
edge_degree_df.shape
# Out:
# (10240, 39)

# %%
poi_df.head()
# Out:
#   SA2_MAIN16  poi_count  poi_count_entropy
# 0  401011001       3288           2.487969
# 1  401011002        756           2.246419
# 2  401021004        279           2.616117
# 3  401021010        153           2.722838
# 4  401031011        276           2.472982

# %%
sa_ids_poi = set(poi_df["SA2_MAIN16"].values)

# %%
edge_degree_df = edge_degree_df[edge_degree_df["sa2_code16_y"].isin(sa_ids_poi)]

# %%
print(edge_degree_df.shape)
# Out:
# (7118, 39)

# %%
edge_degree_df = edge_degree_df[edge_degree_df["sa2_code16_x"].isin(sa_ids_poi)]

# %%
print(edge_degree_df.shape)
# Out:
# (4983, 39)

# %%
count_dic = {key:val for key,val in zip(poi_df["SA2_MAIN16"].values, poi_df["poi_count"].values)}

# %%
entropy_x = []
poi_count_x = []
notin = 0
for sa_id in edge_degree_df["sa2_code16_x"].values:
    if sa_id in entropy:
        entropy_x.append(float(entropy[sa_id]))
        poi_count_x.append(float(count_dic[sa_id]))
    else:
        notin += 1
print(notin)
notin=0
entropy_y = []
poi_count_y = []
for sa_id in edge_degree_df["sa2_code16_y"]:
    if sa_id in entropy:
        entropy_y.append(float(entropy[sa_id]))
        poi_count_y.append(float(count_dic[sa_id]))
    else:
        notin += 1
print(notin)
# Out:
# 0
# 0

# %%
print(len(entropy_x))
print(len(entropy_y))
# Out:
# 4983
# 4983

# %%
edge_degree_df["poi_entropy_x"] = entropy_x
edge_degree_df["poi_entropy_y"] = entropy_y

# %%
edge_degree_df["poi_count_x"] = poi_count_x
edge_degree_df["poi_count_y"] = poi_count_y

# %%
edge_degree_df.shape
# Out:
# (4983, 43)

# %%
edge_degree_df.head()
# Out:
#                         timestamp destination  state     origin  \
# 0   2018-02-01T00:00:00.000+11:00   401011001      4  401011001
# 1   2018-02-01T00:00:00.000+11:00   401011002      4  401011001
# 3   2018-02-01T00:00:00.000+11:00   401021004      4  401011001
# 9   2018-02-01T00:00:00.000+11:00   401021010      4  401011001
# 10  2018-02-01T00:00:00.000+11:00   401031011      4  401011001
#
#     unique_agents  sum_stay_duration  total_stays                  OD  \
# 0           19863          268779414       681217  401011001401011001
# 1            6911            4857456        29322  401011001401011002
# 3            1184             903377         5487  401011001401021004
# 9             685             347208         1897  401011001401021010
# 10           2225            1664328         7709  401011001401031011
#
#     class_ART  class_BUS  ...  num_nodes_y  num_1degree_y  num_2degree_y  \
# 0       208.0       13.0  ...       1642.0          291.0          199.0
# 1       267.0       16.0  ...        517.0          149.0           54.0
# 3       430.0       13.0  ...       2455.0          710.0          502.0
# 9       263.0       13.0  ...       1854.0          535.0          360.0
# 10      255.0       13.0  ...        783.0          178.0           73.0
#
#     num_3degree_y  num_4degree_y  num_greater5degree_y  poi_entropy_x  \
# 0           865.0          276.0                  11.0       2.487969
# 1           239.0           69.0                   6.0       2.487969
# 3          1126.0          110.0                   7.0       2.487969
# 9           911.0           46.0                   2.0       2.487969
# 10          468.0           64.0                   0.0       2.487969
#
#     poi_entropy_y  poi_count_x poi_count_y
# 0        2.487969       3288.0      3288.0
# 1        2.246419       3288.0       756.0
# 3        2.616117       3288.0       279.0
# 9        2.722838       3288.0       153.0
# 10       2.472982       3288.0       276.0
#
# [5 rows x 43 columns]

# %%
# sw. Add the current edge_degree_df and the initial edge_degree_df.pickle 
init_edge_degree_df = pd.read_pickle('../../data_process/edge_degree_df.pickle')
init_edge_degree_df
# Out:
#                            timestamp destination  state     origin  \
# 0      2018-02-01T00:00:00.000+11:00   401011001      4  401011001
# 1      2018-02-01T00:00:00.000+11:00   401011002      4  401011001
# 2      2018-02-01T00:00:00.000+11:00   401021003      4  401011001
# 3      2018-02-01T00:00:00.000+11:00   401021004      4  401011001
# 4      2018-02-01T00:00:00.000+11:00   401021005      4  401011001
# ...                              ...         ...    ...        ...
# 10235  2018-02-01T00:00:00.000+11:00   404031105      4  404031109
# 10236  2018-02-01T00:00:00.000+11:00   404031106      4  404031109
# 10237  2018-02-01T00:00:00.000+11:00   404031107      4  404031109
# 10238  2018-02-01T00:00:00.000+11:00   404031108      4  404031109
# 10239  2018-02-01T00:00:00.000+11:00   404031109      4  404031109
#
#        unique_agents  sum_stay_duration  total_stays                  OD  \
# 0              19863          268779414       681217  401011001401011001
# 1               6911            4857456        29322  401011001401011002
# 2                404             253764         1334  401011001401021003
# 3               1184             903377         5487  401011001401021004
# 4                700             189721         1278  401011001401021005
# ...              ...                ...          ...                 ...
# 10235           2304            5876916        12172  404031109404031105
# 10236           2967            5413932        16935  404031109404031106
# 10237           1811             937583         8366  404031109404031107
# 10238           2464            1334692        11329  404031109404031108
# 10239           5302           68304300       123861  404031109404031109
#
#        class_ART  class_BUS  ...  num_2degree_x  num_3degree_x  num_4degree_x  \
# 0          208.0       13.0  ...          199.0          865.0          276.0
# 1          267.0       16.0  ...          199.0          865.0          276.0
# 2          838.0       82.0  ...          199.0          865.0          276.0
# 3          430.0       13.0  ...          199.0          865.0          276.0
# 4          517.0       13.0  ...          199.0          865.0          276.0
# ...          ...        ...  ...            ...            ...            ...
# 10235       59.0        1.0  ...           20.0          151.0           19.0
# 10236      105.0        1.0  ...           20.0          151.0           19.0
# 10237      262.0        1.0  ...           20.0          151.0           19.0
# 10238      182.0        1.0  ...           20.0          151.0           19.0
# 10239       39.0        1.0  ...           20.0          151.0           19.0
#
#        num_greater5degree_x  num_nodes_y  num_1degree_y  num_2degree_y  \
# 0                      11.0       1642.0          291.0          199.0
# 1                      11.0        517.0          149.0           54.0
# 2                      11.0       4034.0         1174.0          731.0
# 3                      11.0       2455.0          710.0          502.0
# 4                      11.0        989.0          286.0          245.0
# ...                     ...          ...            ...            ...
# 10235                   1.0        157.0           28.0           19.0
# 10236                   1.0        530.0          102.0           39.0
# 10237                   1.0       1036.0          170.0          105.0
# 10238                   1.0        887.0          125.0          120.0
# 10239                   1.0        228.0           37.0           20.0
#
#        num_3degree_y  num_4degree_y num_greater5degree_y
# 0              865.0          276.0                 11.0
# 1              239.0           69.0                  6.0
# 2             1982.0          141.0                  6.0
# 3             1126.0          110.0                  7.0
# 4              421.0           36.0                  1.0
# ...              ...            ...                  ...
# 10235           90.0           20.0                  0.0
# 10236          308.0           81.0                  0.0
# 10237          616.0          143.0                  2.0
# 10238          410.0          231.0                  1.0
# 10239          151.0           19.0                  1.0
#
# [10240 rows x 39 columns]

# %%
# keep all the observations
init_edge_degree_df = init_edge_degree_df.merge(edge_degree_df[['poi_entropy_x', 'poi_entropy_y', 'poi_count_x', 'poi_count_y']], left_index = True, right_index = True, how = 'outer')

# %%
# replace NaN by zeros
init_edge_degree_df.loc[init_edge_degree_df.poi_entropy_x.isna(), ['poi_entropy_x', 'poi_entropy_y', 'poi_count_x', 'poi_count_y']] = 0.0

# %%
init_edge_degree_df
# Out:
#                            timestamp destination  state     origin  \
# 0      2018-02-01T00:00:00.000+11:00   401011001      4  401011001
# 1      2018-02-01T00:00:00.000+11:00   401011002      4  401011001
# 2      2018-02-01T00:00:00.000+11:00   401021003      4  401011001
# 3      2018-02-01T00:00:00.000+11:00   401021004      4  401011001
# 4      2018-02-01T00:00:00.000+11:00   401021005      4  401011001
# ...                              ...         ...    ...        ...
# 10235  2018-02-01T00:00:00.000+11:00   404031105      4  404031109
# 10236  2018-02-01T00:00:00.000+11:00   404031106      4  404031109
# 10237  2018-02-01T00:00:00.000+11:00   404031107      4  404031109
# 10238  2018-02-01T00:00:00.000+11:00   404031108      4  404031109
# 10239  2018-02-01T00:00:00.000+11:00   404031109      4  404031109
#
#        unique_agents  sum_stay_duration  total_stays                  OD  \
# 0              19863          268779414       681217  401011001401011001
# 1               6911            4857456        29322  401011001401011002
# 2                404             253764         1334  401011001401021003
# 3               1184             903377         5487  401011001401021004
# 4                700             189721         1278  401011001401021005
# ...              ...                ...          ...                 ...
# 10235           2304            5876916        12172  404031109404031105
# 10236           2967            5413932        16935  404031109404031106
# 10237           1811             937583         8366  404031109404031107
# 10238           2464            1334692        11329  404031109404031108
# 10239           5302           68304300       123861  404031109404031109
#
#        class_ART  class_BUS  ...  num_nodes_y  num_1degree_y  num_2degree_y  \
# 0          208.0       13.0  ...       1642.0          291.0          199.0
# 1          267.0       16.0  ...        517.0          149.0           54.0
# 2          838.0       82.0  ...       4034.0         1174.0          731.0
# 3          430.0       13.0  ...       2455.0          710.0          502.0
# 4          517.0       13.0  ...        989.0          286.0          245.0
# ...          ...        ...  ...          ...            ...            ...
# 10235       59.0        1.0  ...        157.0           28.0           19.0
# 10236      105.0        1.0  ...        530.0          102.0           39.0
# 10237      262.0        1.0  ...       1036.0          170.0          105.0
# 10238      182.0        1.0  ...        887.0          125.0          120.0
# 10239       39.0        1.0  ...        228.0           37.0           20.0
#
#        num_3degree_y  num_4degree_y  num_greater5degree_y  poi_entropy_x  \
# 0              865.0          276.0                  11.0       2.487969
# 1              239.0           69.0                   6.0       2.487969
# 2             1982.0          141.0                   6.0       0.000000
# 3             1126.0          110.0                   7.0       2.487969
# 4              421.0           36.0                   1.0       0.000000
# ...              ...            ...                   ...            ...
# 10235           90.0           20.0                   0.0       1.717811
# 10236          308.0           81.0                   0.0       1.717811
# 10237          616.0          143.0                   2.0       1.717811
# 10238          410.0          231.0                   1.0       1.717811
# 10239          151.0           19.0                   1.0       1.717811
#
#        poi_entropy_y  poi_count_x poi_count_y
# 0           2.487969       3288.0      3288.0
# 1           2.246419       3288.0       756.0
# 2           0.000000          0.0         0.0
# 3           2.616117       3288.0       279.0
# 4           0.000000          0.0         0.0
# ...              ...          ...         ...
# 10235       2.139979        142.0        44.0
# 10236       1.991836        142.0       129.0
# 10237       2.013120        142.0       353.0
# 10238       2.342724        142.0       334.0
# 10239       1.717811        142.0       142.0
#
# [10240 rows x 43 columns]

# %%
edge_degree_df.to_pickle('../../data_process/edge_degree_entropy_df.pickle')
