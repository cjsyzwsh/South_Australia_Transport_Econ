# %% [markdown]
# # Collect Travel Time using Google API

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import geoplot
from pysal.lib import weights
import networkx as nx
from scipy.spatial import distance
import googlemaps

# %%
## read files
# read spatial files
sa2_adelaide = gpd.read_file('../data_process/shapefiles/sa2_adelaide.shp')

# %%
sa2_adelaide['centroids'] = sa2_adelaide.centroid
# Out:
# /home/jtl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.

# %%
# lat and long
sa2_adelaide['Lat'] = sa2_adelaide.centroids.y
sa2_adelaide['Long'] = sa2_adelaide.centroids.x

# %%
sa2_adelaide.head()
# Out:
#   SA2_MAIN16 SA2_5DIG16          SA2_NAME16 SA3_CODE16      SA3_NAME16  \
# 0  401011001      41001            Adelaide      40101   Adelaide City
# 1  401011002      41002      North Adelaide      40101   Adelaide City
# 2  401021003      41003      Adelaide Hills      40102  Adelaide Hills
# 3  401021004      41004  Aldgate - Stirling      40102  Adelaide Hills
# 4  401021005      41005  Hahndorf - Echunga      40102  Adelaide Hills
#
#   SA4_CODE16                    SA4_NAME16 GCC_CODE16        GCC_NAME16  \
# 0        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 1        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 2        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 3        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
# 4        401  Adelaide - Central and Hills      4GADE  Greater Adelaide
#
#   STE_CODE16       STE_NAME16  AREASQKM16  \
# 0          4  South Australia     10.4824
# 1          4  South Australia      5.0909
# 2          4  South Australia    364.4390
# 3          4  South Australia    117.2141
# 4          4  South Australia    110.1516
#
#                                             geometry  \
# 0  POLYGON ((138.58096 -34.93024, 138.58094 -34.9...
# 1  POLYGON ((138.58214 -34.90424, 138.58287 -34.9...
# 2  POLYGON ((138.75610 -34.82107, 138.75567 -34.8...
# 3  POLYGON ((138.69440 -34.98807, 138.69514 -34.9...
# 4  POLYGON ((138.78877 -35.02474, 138.78889 -35.0...
#
#                      centroids        Lat        Long
# 0  POINT (138.60065 -34.92856) -34.928559  138.600647
# 1  POINT (138.59534 -34.90844) -34.908439  138.595340
# 2  POINT (138.88209 -34.81031) -34.810314  138.882087
# 3  POINT (138.72552 -35.03489) -35.034892  138.725524
# 4  POINT (138.77649 -35.09087) -35.090865  138.776488

# %%
# create a new dataframe
OD = {}
OD['o_idx'] = []
OD['d_idx'] = []
OD['o_sa2_idx'] = []
OD['d_sa2_idx'] = []
OD['o_lat'] = []
OD['o_long'] = []
OD['d_lat'] = []
OD['d_long'] = []

OD
# Out:
# {'o_idx': [],
#  'd_idx': [],
#  'o_sa2_idx': [],
#  'd_sa2_idx': [],
#  'o_lat': [],
#  'o_long': [],
#  'd_lat': [],
#  'd_long': []}

# %%
for i in range(sa2_adelaide.shape[0]):
    print("Origin Index is: ", i)
    o_idx = i
    o_sa2_idx = sa2_adelaide.loc[i, 'SA2_MAIN16']
    o_lat = sa2_adelaide.loc[i, 'Lat']
    o_long = sa2_adelaide.loc[i, 'Long']
    
    for j in range(sa2_adelaide.shape[0]):
        d_idx = j
        d_sa2_idx = sa2_adelaide.loc[j, 'SA2_MAIN16']
        d_lat = sa2_adelaide.loc[j, 'Lat']
        d_long = sa2_adelaide.loc[j, 'Long']
        
        # append
        OD['o_idx'].append(o_idx)
        OD['d_idx'].append(d_idx)
        OD['o_sa2_idx'].append(o_sa2_idx)
# 12095    109    105  404031109  404031105 -34.945974  138.509346 -34.927369
# 12096    109    106  404031109  404031106 -34.945974  138.509346 -34.925414
# 12097    109    107  404031109  404031107 -34.945974  138.509346 -34.957796
# 12098    109    108  404031109  404031108 -34.945974  138.509346 -34.927882
# 12099    109    109  404031109  404031109 -34.945974  138.509346 -34.945974
#
#            d_long
# 0      138.600647
# 1      138.595340
# 2      138.882087
# 3      138.725524
# 4      138.776488
# ...           ...
# 12095  138.513682
# 12096  138.537948
# 12097  138.550445
# 12098  138.566036
# 12099  138.509346
#
# [12100 rows x 8 columns]

# %% [markdown]
# ## Google API Data Collection - One Example

# %%
# gmaps = googlemaps.Client(key=API_key)

# %%
# two example from Google API
# example_idx = 0 # Origin and destination are the same - no error
example_idx = 2 # Origin and destination are different.
o_lat,o_long,d_lat,d_long = OD_df.loc[example_idx, ['o_lat','o_long','d_lat','d_long']]

# %%
origin = (o_lat,o_long)
destination = (d_lat,d_long)

# %%
result = gmaps.distance_matrix(origin, destination, mode = 'driving')

# %%
result
# Out:
# {'destination_addresses': ['Unnamed Road, Gumeracha SA 5233, Australia'],
#  'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#  'rows': [{'elements': [{'distance': {'text': '39.6 km', 'value': 39614},
#      'duration': {'text': '55 mins', 'value': 3293},
#      'status': 'OK'}]}],
#  'status': 'OK'}

# %% [markdown]
# ## Google API Data Collection - All OD Pairs (Run only ONCE)

# %%
OD_time_dic = {}

# %%
# gmaps = googlemaps.Client(key=API_key)

# %%
# DON"T RUN THE CODES...
# One run costs about $100 dollars.

for idx in range(OD_df.shape[0]):
    if idx%100 == 0:
        print(idx)
    o_lat,o_long,d_lat,d_long = OD_df.loc[idx, ['o_lat','o_long','d_lat','d_long']]
    origin = (o_lat,o_long)
    destination = (d_lat,d_long)
    result = gmaps.distance_matrix(origin, destination, mode = 'driving')
    OD_time_dic[idx] = result
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000

# %%
OD_time_dic
# Out:
# {0: {'destination_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  1: {'destination_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '2.9 km', 'value': 2897},
#       'duration': {'text': '9 mins', 'value': 565},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  2: {'destination_addresses': ['Unnamed Road, Gumeracha SA 5233, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '39.6 km', 'value': 39614},
#       'duration': {'text': '55 mins', 'value': 3293},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  3: {'destination_addresses': ['270 Longwood Rd, Heathfield SA 5153, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '20.3 km', 'value': 20319},
#       'duration': {'text': '27 mins', 'value': 1603},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  4: {'destination_addresses': ['185 Diggings Rd, Chapel Hill SA 5153, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '34.7 km', 'value': 34698},
#       'duration': {'text': '36 mins', 'value': 2156},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  5: {'destination_addresses': ['12 Tiers Rd, Woodside SA 5244, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '36.1 km', 'value': 36129},
#       'duration': {'text': '39 mins', 'value': 2321},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  6: {'destination_addresses': ['11 Victoria Cres, Mount Barker SA 5251, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '33.4 km', 'value': 33388},
#       'duration': {'text': '34 mins', 'value': 2049},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  7: {'destination_addresses': ['106 Harper Rd, Mount Barker SA 5251, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '40.4 km', 'value': 40361},
#       'duration': {'text': '37 mins', 'value': 2246},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  8: {'destination_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '39.0 km', 'value': 39009},
#       'duration': {'text': '37 mins', 'value': 2202},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  9: {'destination_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '16.7 km', 'value': 16658},
#       'duration': {'text': '26 mins', 'value': 1573},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  10: {'destination_addresses': ['10 Wynyard Grove, Wattle Park SA 5066, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '6.7 km', 'value': 6697},
#       'duration': {'text': '13 mins', 'value': 785},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  11: {'destination_addresses': ['28 Allandale Ave, Mount Osmond SA 5064, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '7.8 km', 'value': 7824},
#       'duration': {'text': '17 mins', 'value': 1008},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  12: {'destination_addresses': ['7A Christie Ave, Toorak Gardens SA 5065, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '5.2 km', 'value': 5171},
#       'duration': {'text': '10 mins', 'value': 585},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  13: {'destination_addresses': ['5 Shaw St, Athelstone SA 5076, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '13.8 km', 'value': 13767},
#       'duration': {'text': '24 mins', 'value': 1444},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  14: {'destination_addresses': ['17 Roma Grove, Campbelltown SA 5074, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '10.1 km', 'value': 10132},
#       'duration': {'text': '19 mins', 'value': 1148},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  15: {'destination_addresses': ['40 Maud St, Rostrevor SA 5073, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '10.3 km', 'value': 10318},
#       'duration': {'text': '18 mins', 'value': 1079},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  16: {'destination_addresses': ['1 Kingsborough Ln, Norwood SA 5067, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '3.7 km', 'value': 3707},
#       'duration': {'text': '8 mins', 'value': 463},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  17: {'destination_addresses': ['77 Avenue Rd, Payneham SA 5070, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '7.5 km', 'value': 7500},
#       'duration': {'text': '14 mins', 'value': 823},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  18: {'destination_addresses': ['13 Winchester St, St Peters SA 5069, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '5.1 km', 'value': 5054},
#       'duration': {'text': '11 mins', 'value': 657},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  19: {'destination_addresses': ['69 California St, Collinswood SA 5081, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '7.3 km', 'value': 7283},
#       'duration': {'text': '14 mins', 'value': 836},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  20: {'destination_addresses': ['7 Gladstone Rd, Prospect SA 5082, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '5.6 km', 'value': 5607},
#       'duration': {'text': '15 mins', 'value': 911},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  21: {'destination_addresses': ['45 Margaret St, Walkerville SA 5081, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '6.3 km', 'value': 6255},
#       'duration': {'text': '14 mins', 'value': 816},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  22: {'destination_addresses': ['1 Grantley Ave, Millswood SA 5034, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '5.1 km', 'value': 5091},
#       'duration': {'text': '11 mins', 'value': 650},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  23: {'destination_addresses': ['1 Greville St, Fullarton SA 5063, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '4.4 km', 'value': 4434},
#       'duration': {'text': '9 mins', 'value': 562},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  24: {'destination_addresses': ['414 Redbanks Rd, Gawler Belt SA 5118, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '55.9 km', 'value': 55920},
#       'duration': {'text': '46 mins', 'value': 2789},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  25: {'destination_addresses': ['255 Schomburgk Drive, Gawler East SA 5118, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '58.2 km', 'value': 58212},
#       'duration': {'text': '53 mins', 'value': 3200},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  26: {'destination_addresses': ['53-55 Germantown Rd, Two Wells SA 5501, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '43.8 km', 'value': 43783},
#       'duration': {'text': '40 mins', 'value': 2409},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  27: {'destination_addresses': ['39 Washington Dr, Craigmore SA 5114, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '45.6 km', 'value': 45565},
#       'duration': {'text': '44 mins', 'value': 2662},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  28: {'destination_addresses': ['17 Dunbar St, Davoren Park SA 5113, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '41.3 km', 'value': 41309},
#       'duration': {'text': '40 mins', 'value': 2381},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  29: {'destination_addresses': ['6 Twyford St, Elizabeth Grove SA 5112, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '30.1 km', 'value': 30137},
#       'duration': {'text': '38 mins', 'value': 2300},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  30: {'destination_addresses': ['47 Northampton Cres, Elizabeth East SA 5112, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text':
Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '8.8 km', 'value': 8846},
#       'duration': {'text': '18 mins', 'value': 1056},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  92: {'destination_addresses': ['5 Menkens St, Henley Beach SA 5022, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '10.4 km', 'value': 10352},
#       'duration': {'text': '22 mins', 'value': 1293},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  93: {'destination_addresses': ['6 Robert St, Croydon SA 5008, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '5.9 km', 'value': 5937},
#       'duration': {'text': '14 mins', 'value': 863},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  94: {'destination_addresses': ['81 Tapleys Hill Rd, Hendon SA 5014, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '12.8 km', 'value': 12775},
#       'duration': {'text': '24 mins', 'value': 1429},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  95: {'destination_addresses': ['Stop 31 Frederick Rd - East side, Seaton SA 5023, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '12.7 km', 'value': 12681},
#       'duration': {'text': '23 mins', 'value': 1398},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  96: {'destination_addresses': ['14 Martinique Ct, West Lakes SA 5021, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '15.0 km', 'value': 14965},
#       'duration': {'text': '28 mins', 'value': 1654},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  97: {'destination_addresses': ['580 Torrens Rd, Woodville North SA 5012, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '10.8 km', 'value': 10777},
#       'duration': {'text': '21 mins', 'value': 1247},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  98: {'destination_addresses': ['Unnamed Road, Dry Creek SA 5094, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '16.6 km', 'value': 16626},
#       'duration': {'text': '25 mins', 'value': 1476},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  99: {'destination_addresses': ['25 Wellington St, Exeter SA 5019, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '21.2 km', 'value': 21184},
#       'duration': {'text': '29 mins', 'value': 1722},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  100: {'destination_addresses': ['5 Fraser Dr, North Haven SA 5018, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '25.1 km', 'value': 25104},
#       'duration': {'text': '31 mins', 'value': 1888},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  101: {'destination_addresses': ['32 Francis St, Port Adelaide SA 5015, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '18.3 km', 'value': 18258},
#       'duration': {'text': '24 mins', 'value': 1439},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  102: {'destination_addresses': ['606-608 South Rd, Angle Park SA 5010, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '11.4 km', 'value': 11410},
#       'duration': {'text': '18 mins', 'value': 1105},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  103: {'destination_addresses': ['Unnamed Road, Torrens Island SA 5960, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '24.0 km', 'value': 23986},
#       'duration': {'text': '34 mins', 'value': 2032},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  104: {'destination_addresses': ['Tower Rd, Adelaide Airport SA 5950, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '8.0 km', 'value': 7982},
#       'duration': {'text': '19 mins', 'value': 1115},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  105: {'destination_addresses': ['3 Sherwin Ct, Fulham SA 5024, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '8.9 km', 'value': 8890},
#       'duration': {'text': '19 mins', 'value': 1134},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  106: {'destination_addresses': ['21 Myzantha St, Lockleys SA 5032, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '6.7 km', 'value': 6686},
#       'duration': {'text': '15 mins', 'value': 928},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  107: {'destination_addresses': ['21 Dingera Ave, North Plympton SA 5037, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '7.8 km', 'value': 7845},
#       'duration': {'text': '15 mins', 'value': 922},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  108: {'destination_addresses': ['23 Tarragon St, Mile End SA 5031, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '4.4 km', 'value': 4360},
#       'duration': {'text': '11 mins', 'value': 648},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  109: {'destination_addresses': ['Stop 14A West Beach Rd - South side, West Beach SA 5024, Australia'],
#   'origin_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '10.6 km', 'value': 10599},
#       'duration': {'text': '21 mins', 'value': 1233},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  110: {'destination_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '3.2 km', 'value': 3173},
#       'duration': {'text': '9 mins', 'value': 528},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  111: {'destination_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  112: {'destination_addresses': ['Unnamed Road, Gumeracha SA 5233, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '38.0 km', 'value': 38031},
#       'duration': {'text': '54 mins', 'value': 3231},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  113: {'destination_addresses': ['270 Longwood Rd, Heathfield SA 5153, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '23.4 km', 'value': 23397},
#       'duration': {'text': '32 mins', 'value': 1927},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  114: {'destination_addresses': ['185 Diggings Rd, Chapel Hill SA 5153, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '37.8 km', 'value': 37776},
#       'duration': {'text': '41 mins', 'value': 2481},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  115: {'destination_addresses': ['12 Tiers Rd, Woodside SA 5244, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '39.2 km', 'value': 39207},
#       'duration': {'text': '44 mins', 'value': 2645},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  116: {'destination_addresses': ['11 Victoria Cres, Mount Barker SA 5251, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '36.5 km', 'value': 36466},
#       'duration': {'text': '40 mins', 'value': 2374},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  117: {'destination_addresses': ['106 Harper Rd, Mount Barker SA 5251, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '43.4 km', 'value': 43439},
#       'duration': {'text': '43 mins', 'value': 2570},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  118: {'destination_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '42.1 km', 'value': 42087},
#       'duration': {'text': '42 mins', 'value': 2526},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  119: {'destination_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '17.4 km', 'value': 17390},
#       'duration': {'text': '30 mins', 'value': 1809},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  120: {'destination_addresses': ['10 Wynyard Grove, Wattle Park SA 5066, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '9.0 km', 'value': 8967},
#       'duration': {'text': '18 mins', 'value': 1086},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  121: {'destination_addresses': ['28 Allandale Ave, Mount Osmond SA 5064, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '11.3 km', 'value': 11291},
#       'duration': {'text': '22 mins', 'value': 1312},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  122: {'destination_addresses': ['7A Christie Ave, Toorak Gardens SA 5065, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '7.4 km', 'value': 7440},
#       'duration': {'text': '15 mins', 'value': 886},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  123: {'destination_addresses': ['5 Shaw St, Athelstone SA 5076, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '14.2 km', 'value': 14183},
#       'duration': {'text': '25 mins', 'value': 1497},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  124: {'destination_addresses': ['17 Roma Grove, Campbelltown SA 5074, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '10.5 km', 'value': 10548},
#       'duration': {'text': '20 mins', 'value': 1201},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  125: {'destination_addresses': ['40 Maud St, Rostrevor SA 5073, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '11.4 km', 'value': 11354},
#       'duration': {'text': '21 mins', 'value': 1264},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  126: {'destination_addresses': ['1 Kingsborough Ln, Norwood SA 5067, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '6.0 km', 'value': 5976},
#       'duration': {'text': '13 mins', 'value': 764},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  127: {'destination_addresses': ['77 Avenue Rd, Payneham SA 5070, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '7.3 km', 'value': 7317},
#       'duration': {'text': '15 mins', 'value': 881},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  128: {'destination_addresses': ['13 Winchester St, St Peters SA 5069, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '4.8 km', 'value': 4813},
#       'duration': {'text': '10 mins', 'value': 610},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  129: {'destination_addresses': ['69 California St, Collinswood SA 5081, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '3.8 km', 'value': 3828},
#       'duration': {'text': '9 mins', 'value': 541},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  130: {'destination_addresses': ['7 Gladstone Rd, Prospect SA 5082, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '3.0 km', 'value': 2980},
#       'duration': {'text': '8 mins', 'value': 464},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  131: {'destination_addresses': ['45 Margaret St, Walkerville SA 5081, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '3.8 km', 'value': 3756},
#       'duration': {'text': '10 mins', 'value': 587},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  132: {'destination_addresses': ['1 Grantley Ave, Millswood SA 5034, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '6.1 km', 'value': 6076},
#       'duration': {'text': '14 mins', 'value': 824},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  133: {'destination_addresses': ['1 Greville St, Fullarton SA 5063, Australia'],
#   'origin_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '7.9 km', 'value': 7920},
#       'duration': {'text': '16 mins', 'value': 950},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#
Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '62.3 km', 'value': 62330},
#       'duration': {'text': '1 hour 4 mins', 'value': 3815},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  981: {'destination_addresses': ['32 Francis St, Port Adelaide SA 5015, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '55.5 km', 'value': 55484},
#       'duration': {'text': '56 mins', 'value': 3366},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  982: {'destination_addresses': ['606-608 South Rd, Angle Park SA 5010, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '48.6 km', 'value': 48636},
#       'duration': {'text': '51 mins', 'value': 3032},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  983: {'destination_addresses': ['Unnamed Road, Torrens Island SA 5960, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '61.2 km', 'value': 61212},
#       'duration': {'text': '1 hour 6 mins', 'value': 3959},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  984: {'destination_addresses': ['Tower Rd, Adelaide Airport SA 5950, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '46.7 km', 'value': 46731},
#       'duration': {'text': '51 mins', 'value': 3066},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  985: {'destination_addresses': ['3 Sherwin Ct, Fulham SA 5024, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '48.4 km', 'value': 48380},
#       'duration': {'text': '52 mins', 'value': 3141},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  986: {'destination_addresses': ['21 Myzantha St, Lockleys SA 5032, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '46.2 km', 'value': 46178},
#       'duration': {'text': '49 mins', 'value': 2966},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  987: {'destination_addresses': ['21 Dingera Ave, North Plympton SA 5037, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '42.5 km', 'value': 42538},
#       'duration': {'text': '43 mins', 'value': 2551},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  988: {'destination_addresses': ['23 Tarragon St, Mile End SA 5031, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '43.0 km', 'value': 43037},
#       'duration': {'text': '44 mins', 'value': 2621},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  989: {'destination_addresses': ['Stop 14A West Beach Rd - South side, West Beach SA 5024, Australia'],
#   'origin_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '49.4 km', 'value': 49446},
#       'duration': {'text': '51 mins', 'value': 3070},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  990: {'destination_addresses': ['Torrens Buidling, Adelaide SA 5000, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '17.2 km', 'value': 17202},
#       'duration': {'text': '29 mins', 'value': 1750},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  991: {'destination_addresses': ['34 Walter St, North Adelaide SA 5006, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '17.4 km', 'value': 17419},
#       'duration': {'text': '29 mins', 'value': 1738},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  992: {'destination_addresses': ['Unnamed Road, Gumeracha SA 5233, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '33.3 km', 'value': 33313},
#       'duration': {'text': '44 mins', 'value': 2659},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  993: {'destination_addresses': ['270 Longwood Rd, Heathfield SA 5153, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '16.8 km', 'value': 16775},
#       'duration': {'text': '24 mins', 'value': 1461},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  994: {'destination_addresses': ['185 Diggings Rd, Chapel Hill SA 5153, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '27.1 km', 'value': 27062},
#       'duration': {'text': '34 mins', 'value': 2048},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  995: {'destination_addresses': ['12 Tiers Rd, Woodside SA 5244, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '17.6 km', 'value': 17600},
#       'duration': {'text': '23 mins', 'value': 1386},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  996: {'destination_addresses': ['11 Victoria Cres, Mount Barker SA 5251, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '28.4 km', 'value': 28398},
#       'duration': {'text': '32 mins', 'value': 1933},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  997: {'destination_addresses': ['106 Harper Rd, Mount Barker SA 5251, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '35.4 km', 'value': 35372},
#       'duration': {'text': '36 mins', 'value': 2130},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  998: {'destination_addresses': ['58 North Rd, Nairne SA 5252, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '29.2 km', 'value': 29159},
#       'duration': {'text': '35 mins', 'value': 2102},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  999: {'destination_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'origin_addresses': ['146C Green Valley Rd, Norton Summit SA 5136, Australia'],
#   'rows': [{'elements': [{'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  ...}

# %% [markdown]
# ## Augment Google API data

# %%
OD_from_google_api = {}

OD_from_google_api['idx'] = [] # Important for combining two dfs
OD_from_google_api['d_address'] = []
OD_from_google_api['o_address'] = []
OD_from_google_api['od_duration_text'] = []
OD_from_google_api['od_duration_value'] = []
OD_from_google_api['od_distance_text'] = []
OD_from_google_api['od_distance_value'] = []

# %%
for key in OD_time_dic.keys():
    if key%100 == 0:
        print(key)    
    OD_from_google_api['idx'].append(key)
    OD_from_google_api['d_address'].append(OD_time_dic[key]['destination_addresses'][0])
    OD_from_google_api['o_address'].append(OD_time_dic[key]['origin_addresses'][0])
    OD_from_google_api['od_duration_text'].append(OD_time_dic[key]['rows'][0]['elements'][0]['duration']['text'])
    OD_from_google_api['od_duration_value'].append(OD_time_dic[key]['rows'][0]['elements'][0]['duration']['value'])
    OD_from_google_api['od_distance_text'].append(OD_time_dic[key]['rows'][0]['elements'][0]['distance']['text'])
    OD_from_google_api['od_distance_value'].append(OD_time_dic[key]['rows'][0]['elements'][0]['distance']['value'])
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000

# %%
OD_from_google_api_df = pd.DataFrame(OD_from_google_api)

# %%
OD_from_google_api_df
# Out:
#          idx                                          d_address  \
# 0          0      Torrens Buidling, Adelaide SA 5000, Australia
# 1          1    34 Walter St, North Adelaide SA 5006, Australia
# 2          2         Unnamed Road, Gumeracha SA 5233, Australia
# 3          3     270 Longwood Rd, Heathfield SA 5153, Australia
# 4          4    185 Diggings Rd, Chapel Hill SA 5153, Australia
# ...      ...                                                ...
# 12095  12095            3 Sherwin Ct, Fulham SA 5024, Australia
# 12096  12096        21 Myzantha St, Lockleys SA 5032, Australia
# 12097  12097  21 Dingera Ave, North Plympton SA 5037, Australia
# 12098  12098        23 Tarragon St, Mile End SA 5031, Australia
# 12099  12099  Stop 14A West Beach Rd - South side, West Beac...
#
#                                                o_address od_duration_text  \
# 0          Torrens Buidling, Adelaide SA 5000, Australia            1 min
# 1          Torrens Buidling, Adelaide SA 5000, Australia           9 mins
# 2          Torrens Buidling, Adelaide SA 5000, Australia          55 mins
# 3          Torrens Buidling, Adelaide SA 5000, Australia          27 mins
# 4          Torrens Buidling, Adelaide SA 5000, Australia          36 mins
# ...                                                  ...              ...
# 12095  Stop 14A West Beach Rd - South side, West Beac...           6 mins
# 12096  Stop 14A West Beach Rd - South side, West Beac...           9 mins
# 12097  Stop 14A West Beach Rd - South side, West Beac...          10 mins
# 12098  Stop 14A West Beach Rd - South side, West Beac...          12 mins
# 12099  Stop 14A West Beach Rd - South side, West Beac...            1 min
#
#        od_duration_value od_distance_text  od_distance_value
# 0                      0              1 m                  0
# 1                    565           2.9 km               2897
# 2                   3293          39.6 km              39614
# 3                   1603          20.3 km              20319
# 4                   2156          34.7 km              34698
# ...                  ...              ...                ...
# 12095                345           3.3 km               3289
# 12096                528           5.1 km               5066
# 12097                572           6.6 km               6601
# 12098                695           6.9 km               6931
# 12099                  0              1 m                  0
#
# [12100 rows x 7 columns]

# %%
# merge
OD_merged_google_api =  OD_df.merge(OD_from_google_api_df, left_index=True, right_index=True)
OD_merged_google_api
# Out:
#        o_idx  d_idx  o_sa2_idx  d_sa2_idx      o_lat      o_long      d_lat  \
# 0          0      0  401011001  401011001 -34.928559  138.600647 -34.928559
# 1          0      1  401011001  401011002 -34.928559  138.600647 -34.908439
# 2          0      2  401011001  401021003 -34.928559  138.600647 -34.810314
# 3          0      3  401011001  401021004 -34.928559  138.600647 -35.034892
# 4          0      4  401011001  401021005 -34.928559  138.600647 -35.090865
# ...      ...    ...        ...        ...        ...         ...        ...
# 12095    109    105  404031109  404031105 -34.945974  138.509346 -34.927369
# 12096    109    106  404031109  404031106 -34.945974  138.509346 -34.925414
# 12097    109    107  404031109  404031107 -34.945974  138.509346 -34.957796
# 12098    109    108  404031109  404031108 -34.945974  138.509346 -34.927882
# 12099    109    109  404031109  404031109 -34.945974  138.509346 -34.945974
#
#            d_long    idx                                          d_address  \
# 0      138.600647      0      Torrens Buidling, Adelaide SA 5000, Australia
# 1      138.595340      1    34 Walter St, North Adelaide SA 5006, Australia
# 2      138.882087      2         Unnamed Road, Gumeracha SA 5233, Australia
# 3      138.725524      3     270 Longwood Rd, Heathfield SA 5153, Australia
# 4      138.776488      4    185 Diggings Rd, Chapel Hill SA 5153, Australia
# ...           ...    ...                                                ...
# 12095  138.513682  12095            3 Sherwin Ct, Fulham SA 5024, Australia
# 12096  138.537948  12096        21 Myzantha St, Lockleys SA 5032, Australia
# 12097  138.550445  12097  21 Dingera Ave, North Plympton SA 5037, Australia
# 12098  138.566036  12098        23 Tarragon St, Mile End SA 5031, Australia
# 12099  138.509346  12099  Stop 14A West Beach Rd - South side, West Beac...
#
#                                                o_address od_duration_text  \
# 0          Torrens Buidling, Adelaide SA 5000, Australia            1 min
# 1          Torrens Buidling, Adelaide SA 5000, Australia           9 mins
# 2          Torrens Buidling, Adelaide SA 5000, Australia          55 mins
# 3          Torrens Buidling, Adelaide SA 5000, Australia          27 mins
# 4          Torrens Buidling, Adelaide SA 5000, Australia          36 mins
# ...                                                  ...              ...
# 12095  Stop 14A West Beach Rd - South side, West Beac...           6 mins
# 12096  Stop 14A West Beach Rd - South side, West Beac...           9 mins
# 12097  Stop 14A West Beach Rd - South side, West Beac...          10 mins
# 12098  Stop 14A West Beach Rd - South side, West Beac...          12 mins
# 12099  Stop 14A West Beach Rd - South side, West Beac...            1 min
#
#        od_duration_value od_distance_text  od_distance_value
# 0                      0              1 m                  0
# 1                    565           2.9 km               2897
# 2                   3293          39.6 km              39614
# 3                   1603          20.3 km              20319
# 4                   2156          34.7 km              34698
# ...                  ...              ...                ...
# 12095                345           3.3 km               3289
# 12096                528           5.1 km               5066
# 12097                572           6.6 km               6601
# 12098                695           6.9 km               6931
# 12099                  0              1 m                  0
#
# [12100 rows x 15 columns]

# %% [markdown]
# # Save Google API Info

# %%
# Save 1 - raw outputs from Google API
import pickle

with open("../data/OD_Google_API_raw.pickle", 'wb') as w:
    pickle.dump(OD_time_dic, w, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Save 2 - augmented output to facilitate future usage. 
with open("../data/OD_Google_API_With_Map_Info.pickle", 'wb') as w:
    pickle.dump(OD_merged_google_api, w, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# create a txt file for Google API

# %%
# # read 
# with open("../data/OD_Google_API_With_Map_Info.pickle", 'rb') as w:
#     OD_dic_read = pickle.load(w)
