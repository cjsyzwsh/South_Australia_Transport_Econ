# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import geoplot
import pickle
import geoplot.crs as gcrs
import statsmodels.api as sm
# Out:
# /home/jasonllu/anaconda3/lib/python3.7/site-packages/geopandas/_compat.py:88: UserWarning: The Shapely GEOS version (3.9.0-CAPI-1.14.1) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
mount_path = "/mnt/c/Users/jason/Dropbox (MIT)/"
#mount_path = "/Users/shenhaowang/Dropbox (MIT)/project_media_lab_South_Australia/"

# %%
social_economic_df = pd.read_csv(mount_path + "/SA data/NATSEM_-_Social_and_Economic_Indicators_-_Indigenous_Indicators_SA2_2016.csv/data6735501229514139095.csv")

# %%
social_economic_df = social_economic_df.dropna()

# %%
social_economic_df.columns
# Out:
# Index(['perc_indig_age_0_14', ' perc_indig_hsld_equiv_inc_less_than_300',
#        ' perc_indig_rent_oth_dwl', ' perc_indig_no_vehicle_in_hsld',
#        ' perc_indig_age_65_over', ' perc_indig_rent_priv_dwl',
#        ' perc_indig_rent_pub_dwl', ' perc_indig_f',
#        ' perc_indig_owned_outright_dwl', ' perc_indig_age_35_64',
#        ' perc_indig_age_15plus_edu_degree_diploma_certificate',
#        ' perc_indig_hsld_equiv_inc_1000_1500',
#        ' perc_indig_1_or_more_vehicle_in_hsld',
#        ' perc_indig_hsld_equiv_inc_above_1500',
#        ' perc_indig_hsld_equiv_inc_300_1000', ' sa2_code16', ' perc_indig_m',
#        ' perc_indig_age_15_34', ' perc_indig_age_15plus_edu_none'],
#       dtype='object')

# %%
social_economic_df.rename(columns= {" sa2_code16":"SA2_MAIN16"},inplace=True)

# %%
helper = [str(elt) for elt in social_economic_df["SA2_MAIN16"].values]

# %%
helper
# Out:
# ['403041087',
#  '402051049',
#  '405011114',
#  '405011110',
#  '405011111',
#  '405011113',
#  '405031123',
#  '405041125',
#  '406011129',
#  '406011130',
#  '406011131',
#  '405041124',
#  '407021151',
#  '406011133',
#  '406011134',
#  '401051017',
#  '401071024',
#  '402011026',
#  '402011027',
#  '402011025',
#  '401061021',
#  '401021008',
#  '407021152',
#  '407021154',
#  '403041086',
#  '401041016',
#  '407031164',
#  '401061020',
#  '401021007',
#  '401011001',
#  '401021004',
#  '401021006',
#  '401031011',
#  '401041014',
#  '401051018',
#  '401031012',
#  '402041043',
#  '401041015',
#  '402021035',
#  '401071023',
#  '403021062',
#  '401051019',
#  '401061022',
#  '402021028',
#  '402021029',
#  '403041085',
#  '402021030',
#  '402021031',
#  '402021032',
#  '402021034',
#  '402031036',
#  '402031037',
#  '402031038',
#  '402041047',
#  '402041040',
#  '402041041',
#  '402041044',
#  '402041046',
#  '402041048',
#  '402041171',
#  '402041172',
#  '402051050',
# ...

# %%
social_economic_df["SA2_MAIN16"] = helper

# %%
social_economic_df.head()
# Out:
#    perc_indig_age_0_14   perc_indig_hsld_equiv_inc_less_than_300  \
# 0            43.157894                                 17.041801
# 1            38.823530                                 10.526316
# 5            27.941177                                 17.241379
# 7            35.593220                                  5.660378
# 8            28.571428                                  4.444445
#
#     perc_indig_rent_oth_dwl   perc_indig_no_vehicle_in_hsld  \
# 0                  1.166181                        9.302325
# 1                  0.000000                        7.894737
# 5                  0.000000                        5.970149
# 7                  0.000000                        0.000000
# 8                  0.000000                        3.092783
#
#     perc_indig_age_65_over   perc_indig_rent_priv_dwl  \
# 0                 2.894737                  44.023323
# 1                10.588235                  29.729730
# ...

# %%
social_economic_df.shape
# Out:
# (141, 19)

# %%
node_degree_entropy_df = pd.read_pickle('../../data_process/node_degree_entropy_df.pickle')

# %%
node_degree_entropy_df = node_degree_entropy_df.merge(social_economic_df, how="left", on="SA2_MAIN16")

# %%
node_degree_entropy_df
# Out:
#     SA2_MAIN16 SA2_5DIG16          SA2_NAME16 SA3_CODE16      SA3_NAME16  \
# 0    401011001      41001            Adelaide      40101   Adelaide City
# 1    401011002      41002      North Adelaide      40101   Adelaide City
# 2    401021003      41003      Adelaide Hills      40102  Adelaide Hills
# 3    401021004      41004  Aldgate - Stirling      40102  Adelaide Hills
# 4    401021005      41005  Hahndorf - Echunga      40102  Adelaide Hills
# ..         ...        ...                 ...        ...             ...
# 98   404031105      41105              Fulham      40403    West Torrens
# 99   404031106      41106            Lockleys      40403    West Torrens
# 100  404031107      41107            Plympton      40403    West Torrens
# 101  404031108      41108       Richmond (SA)      40403    West Torrens
# 102  404031109      41109          West Beach      40403    West Torrens
#
#     SA4_CODE16                    SA4_NAME16 GCC_CODE16        GCC_NAME16  \
# ...

# %%
node_degree_entropy_df.shape
# Out:
# (103, 68)

# %%
node_degree_entropy_df = node_degree_entropy_df.dropna()

# %%
node_degree_entropy_df.shape
# Out:
# (89, 68)

# %%
node_degree_entropy_df.to_pickle("../../data_process/node_degree_entropy_social_indigenous_df.pickle")
